# %%
# region <set up parameters>

import os
import csv
import pandas as pd
import multiprocessing

sample_size = 5
min_distance = 2
random_seed = 4
network_type = "drive"
point_distance_size = 5000
experiment_name = "2026_1_2km_drive"

base_path = os.path.expanduser(
    os.path.join("~/proj/nobackup/streetnetwork-alignment/", experiment_name)
)

print(base_path)
min_od_distance = 1000
max_od_distance = 2000
od_pair_sample_size = 2


if not os.path.exists(base_path):
    print("creating path")
    os.makedirs(base_path)

parameters_file_path = os.path.join(base_path, "parameters.csv")
city_sample_nodes_path = os.path.join(
    base_path, f"city_sample_nodes_{experiment_name}.csv"
)
local_graph_folder = os.path.join(base_path, "local_origin_graphs")

with open(parameters_file_path, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Parameter", "Value"])
    writer.writerow(["sample_size", sample_size])
    writer.writerow(["min_distance", min_distance])
    writer.writerow(["random_seed", random_seed])
    writer.writerow(["network_type", network_type])
    writer.writerow(["point_distance_size", point_distance_size])
    writer.writerow(["min_od_distance", min_od_distance])
    writer.writerow(["max_od_distance", max_od_distance])
    writer.writerow(["base_path", base_path])
    writer.writerow(["city_sample_nodes_path", city_sample_nodes_path])
    writer.writerow(["local_graph_folder", local_graph_folder])
    writer.writerow(["base_path", base_path])
    writer.writerow(["experiment_name", experiment_name])


param = pd.read_csv(parameters_file_path)
display(param)

num_processes = (
    multiprocessing.cpu_count()
)  # Adjust based on your system's capabilities
print(f"Number of processes to use: {num_processes}")

# endregion
# Out:
# /home/arvidh/proj/nobackup/streetnetwork-alignment/2025-08-2000m_dataset
# creating path
#                  Parameter                                              Value
# 0              sample_size                                                  1
# 1             min_distance                                                  2
# 2              random_seed                                                  4
# 3             network_type                                              drive
# 4      point_distance_size                                               1000
# 5          min_od_distance                                               1000
# 6          max_od_distance                                               2000
# 7                base_path  /home/arvidh/proj/nobackup/streetnetwork-align...
# 8   city_sample_nodes_path  /home/arvidh/proj/nobackup/streetnetwork-align...
# 9       local_graph_folder  /home/arvidh/proj/nobackup/streetnetwork-align...
# 10               base_path  /home/arvidh/proj/nobackup/streetnetwork-align...
# 11         experiment_name                              2025-08-2000m_dataset
# Number of processes to use: 8

# %%
# region <get node sample from cities>
# The workflow for analyzing the routes begins with coordinate points used as origin locations.
import os
import pandas as pd
from route_network_analysis import node_sampling

df = pd.read_csv("1_city_sample.csv")

city_sample_nodes_path = os.path.join(
    base_path, f"city_sample_nodes_{experiment_name}.csv"
)

if os.path.exists(city_sample_nodes_path):
    print("sample nodes already retrieved")
else:
    node_sample_df = node_sampling.get_random_nodes_for_all_cities(
        df,
        min_distance_km=min_distance,
        sample_size=sample_size,
        random_seed=random_seed,
    )
    node_sample_df["graph_path"] = node_sample_df.apply(
        lambda row: os.path.join(
            local_graph_folder, f"{row['city_name_en']}_{row['node_id']}.graphml"
        ),
        axis=1,
    )
    node_sample_df.to_csv(os.path.join(base_path, city_sample_nodes_path))

# endregion
# Out:
# Random nodes for Barcelona that are at least 2 km apart: [600112315]
# Random nodes for Barcelona: [600112315]
# Node: 600112315
# Random node coordinates for Barcelona: 41.4433598, 2.2059766

# %%
# region <create graphs>
import os  # for file operations
import pandas as pd  # for reading the csv file
import joblib
import logging
import ast
import route_network_analysis as rna
import osmnx as ox

logging.basicConfig(
    level=logging.ERROR,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filename="jupyter.log",
    filemode="w",
)

#
sub_folder = "local_origin_graphs"
local_graph_folder = os.path.join(base_path, sub_folder)
if not os.path.exists(local_graph_folder):
    os.makedirs(local_graph_folder)

print(city_sample_nodes_path)
df = pd.read_csv(city_sample_nodes_path)
print(df["graph_path"])


def create_graphs(row):
    if os.path.exists(row["graph_path"]):
        print(f"Graph exists: {row['graph_path']}")
        return True, row["city_name"], row["node_id"]
    else:
        print(f"---Graph missing: {row['graph_path']}---")
        # Apply the function asynchronously
    try:
        latlon_point = ast.literal_eval(row["node_latlon"])
        og = rna.origin_graph(
            origin_point=latlon_point,
            distance_from_point=point_distance_size,
            city_name=row["city_name_en"],
            network_type=network_type,
            remove_parallel=True,
            simplify=True,
        )

        og.save_graph(row["graph_path"])

        # Plot the origin graph to see if something is obviously wrong
        ox.plot_graph(
            og.graph,
            node_color="blue",
            node_size=5,
            edge_linewidth=1,
            edge_color="black",
            bgcolor="white",
            save=True,
            filepath=os.path.join(
                local_graph_folder, f"{row['city_name']}_{row['node_id']}.png"
            ),
            show=False,
        )
        logging.error(f"Finished with graph: {row['graph_path']}")
        return True, row["city_name"], row["node_id"]

    except Exception as e:
        logging.error(f"error {e} creating {row['graph_path']}")
        return False, row["city_name"], row["node_id"], e


# Number of processes to use
num_processes = joblib.cpu_count() - 2
print(f"Number of processes to use: {num_processes}")

# Collect results from joblib
results = []
try:
    results = joblib.Parallel(n_jobs=num_processes, backend="loky")(
        joblib.delayed(create_graphs)(row) for _, row in df.iterrows()
    )
except Exception as e:
    print(f"Joblib parallel processing error: {e}")

for result in results:
    if not result[0]:
        print(f"failed creating graph {result[1]}{result[2]}. error {result[3]}")
    else:
        print(f"finished creating graph {result[1]}{result[2]}")

print("finished")

# endregion
# Out:
# /home/arvidh/proj/nobackup/streetnetwork-alignment/2025-08-2000m_dataset/city_sample_nodes_2025-08-2000m_dataset.csv
# 0    /home/arvidh/proj/nobackup/streetnetwork-align...
# Name: graph_path, dtype: object
# Number of processes to use: 6
# finished creating graph Barcelona600112315
# finished

# %%
# The next step is to add weights to the edges of the graph.
import pandas as pd  # for reading the csv file
import joblib  # replacing multiprocessing with joblib
import route_network_analysis as rna

df = pd.read_csv(city_sample_nodes_path)
df["weights_added"] = False


# if 'weights_added' not in df.columns:
#    df['weights_added'] = False
def add_graph_weights(row):
    og = rna.origin_graph.from_graphml(graphml_path=row["graph_path"])
    og.add_simplest_paths_from_origin()
    og.add_weights("deviation_from_prototypical")
    og.add_weights("node_degree")
    og.add_weights("instruction_equivalent")
    og.add_weights("betweenness_centrality")
    og.save_graph(row["graph_path"])
    print(
        f"Finished with graph: {row['city_name_en']} node: {row['node_id']}", flush=True
    )
    return True, row["city_name_en"], row["node_id"]


# Number of processes to use
num_processes = joblib.cpu_count() - 2
print(f"Number of processes to use: {num_processes}")
# Collect results from joblib
rows_to_process = []
for idx, row in df.iterrows():
    rows_to_process.append(row)


results = joblib.Parallel(n_jobs=num_processes, backend="loky")(
    joblib.delayed(add_graph_weights)(row) for row in rows_to_process
)


for result in results:
    if result[0]:
        mask = (df["city_name_en"] == result[1]) & (df["node_id"] == result[2])
        df.loc[mask, "weights_added"] = True
df.to_csv(city_sample_nodes_path, index=False)
# Out:
# Number of processes to use: 6
# Finished with graph: Barcelona node: 600112315

# %%
import pandas as pd  # for reading the csv file
import joblib  # replacing multiprocessing with joblib
import route_network_analysis as rna

df = pd.read_csv(city_sample_nodes_path)
display(df)
local_odpair_folder = os.path.join(base_path, "od_pair_data")
local_odpair_base_folder = os.path.join(local_odpair_folder, "base")
local_odpair_geom_folder = os.path.join(local_odpair_folder, "geom")
print(f"odpair data will be stored at {local_odpair_folder}")
os.makedirs(local_odpair_folder, exist_ok=True)
os.makedirs(local_odpair_base_folder, exist_ok=True)
os.makedirs(local_odpair_geom_folder, exist_ok=True)


df["od_pairs_added"] = False


def get_od_pairs(row):
    print(
        f"Finding OD_pairs for graph: {row['city_name_en']} node: {row['node_id']}",
        flush=True,
    )
    og = rna.origin_graph.from_graphml(graphml_path=row["graph_path"])
    og.create_od_pairs(
        min_radius=min_od_distance,
        max_radius=max_od_distance,
        sample_size=od_pair_sample_size,
    )
    od_pair_data = og.get_od_pair_data()
    od_pair_geom_data = og.get_od_pair_geom_data()
    json_base_path = os.path.join(
        local_odpair_base_folder, f"od_pair_{row['city_name_en']}_{row['node_id']}.json"
    )
    json_geom_path = os.path.join(
        local_odpair_geom_folder,
        f"od_pair_geom_{row['city_name_en']}_{row['node_id']}.json",
    )
    od_pair_data.to_json(
        json_base_path, orient="records", default_handler=str, indent=2
    )
    od_pair_geom_data.to_json(
        json_geom_path, orient="records", default_handler=str, indent=2
    )
    print(
        f"Finished finding OD_pairs for graph: {row['city_name_en']} node: {row['node_id']}",
        flush=True,
    )
    return True, row["city_name_en"], row["node_id"]


num_processes = joblib.cpu_count() - 4
print(f"Number of processes to use: {num_processes}")


rows_to_process = []
for idx, row in df.iterrows():
    # if not row['od_pairs_added']:
    rows_to_process.append(row)

results = joblib.Parallel(n_jobs=num_processes, backend="loky")(
    joblib.delayed(get_od_pairs)(row) for row in rows_to_process
)

for result in results:
    if result[0]:
        mask = (df["city_name_en"] == result[1]) & (df["node_id"] == result[2])
        df.loc[mask, "od_pairs_added"] = True


import glob


# Get all json files from od_pair_data folder
od_pair_base_files = glob.glob(os.path.join(local_odpair_base_folder, "*.json"))
od_pair_geom_files = glob.glob(os.path.join(local_odpair_geom_folder, "*.json"))
# Read and combine all json files
od_pair_base_data = pd.concat(
    [pd.read_json(f) for f in od_pair_base_files], ignore_index=False
)
od_pair_geom_data = pd.concat(
    [pd.read_json(f) for f in od_pair_geom_files], ignore_index=False
)

print(f"Total number of od-pairs: {len(od_pair_base_data)}")
print(od_pair_base_data.columns)


# The od-pair data contains lists and dictionaries that are not easily saved to a csv file, so we store it as a json file.
# Still, there some columns that need to be serialized to strings such as shapely polygon objects.


od_pair_data_geom_path_json = os.path.join(
    local_odpair_folder, "origin_od_pair_geom.json"
)
od_pair_data_base_path_csv = os.path.join(
    local_odpair_folder, "origin_od_pair_base.csv"
)

od_pair_base_data.to_csv(od_pair_data_base_path_csv)
od_pair_geom_data.to_json(
    od_pair_data_geom_path_json, orient="records", default_handler=str, indent=2
)

print("done")
# Out:
#    Unnamed: 0.1  Unnamed: 0  city_name city_name_en country_name  \
# 0             0           0  Barcelona    Barcelona       España
#
#   country_name_en continent  region network_type    node_id  \
# 0           Spain    Europe  Europe        drive  600112315
#
#                node_latlon                                         graph_path  \
# 0  (41.4433598, 2.2059766)  /home/arvidh/proj/nobackup/streetnetwork-align...
#
#    weights_added
# 0           True
# odpair data will be stored at /home/arvidh/proj/nobackup/streetnetwork-alignment/2025-08-2000m_dataset/od_pair_data
# Number of processes to use: 4
# ---Graph missing: /home/arvidh/proj/nobackup/streetnetwork-alignment/2025-08-2000m_dataset/local_origin_graphs/Barcelona_600112315.graphml---
# Graph exists: /home/arvidh/proj/nobackup/streetnetwork-alignment/2025-08-2000m_dataset/local_origin_graphs/Barcelona_600112315.graphml
# Finding OD_pairs for graph: Barcelona node: 600112315
# Finished finding OD_pairs for graph: Barcelona node: 600112315
# Total number of od-pairs: 2
# Index(['id', 'city_name', 'origin_node', 'origin_point', 'destination_node',
#        'destination_point', 'od_distance', 'od_cardinal_direction',
#        'cot_alignment', 'cot_dist_alignment',
#        'bearings_dist_env_directed_dist_weighted',
#        'bearings_dist_env_directed_dist',
#        'bearings_dist_env_undirected_dist_weighted',
#        'bearings_dist_env_undirected_dist', 'bearings_dist_od_undirected_dist',
#        'bearings_dist_od_directed_dist',
#        'bearings_dist_od_undirected_dist_perp',
#        'bearing_dist_prop_environment_orientation_entropy_weighted',
#        'bearing_dist_prop_environment_orientation_entropy',
#        'bearing_dist_prop_environment_orientation_order_weighted',
#        'bearing_dist_prop_environment_orientation_order',
#        'bearing_dist_prop_environment_orientation_directed_entropy_weighted',
#        'bearing_dist_prop_environment_orientation_directed_entropy',
#        'bearing_dist_prop_environment_orientation_order_directed_weighted',
#        'bearing_dist_prop_environment_orientation_order_directed',
#        'subgraph_stats_n', 'subgraph_stats_m', 'subgraph_stats_k_avg',
#        'subgraph_stats_edge_length_total', 'subgraph_stats_edge_length_avg',
#        'subgraph_stats_streets_per_node_avg',
#        'subgraph_stats_streets_per_node_counts',
#        'subgraph_stats_streets_per_node_proportions',
#        'subgraph_stats_intersection_count',
#        'subgraph_stats_street_length_total',
#        'subgraph_stats_street_segment_count',
#        'subgraph_stats_street_length_avg', 'subgraph_stats_circuity_avg',
#        'subgraph_stats_self_loop_proportion', 'subgraph_stats_node_density_km',
#        'subgraph_stats_intersection_density_km',
#        'subgraph_stats_edge_density_km', 'subgraph_stats_street_density_km',
#        'subgraph_stats_avg_node_betweenness', 'subgraph_stats_area',
#        'shortest_identifier', 'shortest_length', 'shortest_n_nodes',
#        'shortest_n_segments', 'shortest_directed_bearings',
#        'shortest_directed_weights', 'shortest_undirected_bearings',
#        'shortest_undirected_weights', 'shortest_undirected_bearing_dist',
#        'shortest_undirected_bearing_dist_weighted',
#        'shortest_directed_bearing_dist',
#        'shortest_directed_bearing_dist_weighted', 'shortest_complexity',
#        'shortest_complexity_list', 'shortest_turn_types',
#        'shortest_turn_count', 'shortest_turn_frequency',
#        'shortest_total_turn_degree', 'shortest_total_turn_degree_abs',
#        'shortest_avg_turn_degree', 'shortest_sum_deviation_from_prototypical',
#        'shortest_avg_deviation_from_prototypical', 'shortest_sum_node_degree',
#        'shortest_avg_node_degree', 'shortest_sum_instruction_equivalent',
#        'simplest_identifier', 'simplest_length', 'simplest_n_nodes',
#        'simplest_n_segments', 'simplest_directed_bearings',
#        'simplest_directed_weights', 'simplest_undirected_bearings',
#        'simplest_undirected_weights', 'simplest_undirected_bearing_dist',
#        'simplest_undirected_bearing_dist_weighted',
#        'simplest_directed_bearing_dist',
#        'simplest_directed_bearing_dist_weighted', 'simplest_complexity',
#        'simplest_complexity_list', 'simplest_turn_types',
#        'simplest_turn_count', 'simplest_turn_frequency',
#        'simplest_total_turn_degree', 'simplest_total_turn_degree_abs',
#        'simplest_avg_turn_degree', 'simplest_sum_deviation_from_prototypical',
#        'simplest_avg_deviation_from_prototypical', 'simplest_sum_node_degree',
#        'simplest_avg_node_degree', 'simplest_sum_instruction_equivalent',
#        'length_diff', 'complexity_diff', 'shortest_diff', 'hausdorff_diff',
#        'graph_path'],
#       dtype='object')
# done
